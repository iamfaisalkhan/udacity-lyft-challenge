# %%
import sys
import os
sys.path.append('../../')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from skimage.io import imread

from gen.load_data import load_data

# %%
from sklearn.utils import shuffle

train_df, valid_df, test_df = load_data('../../data')


print(train_df.head())
# Out:
#                                                image                   id  \
# 0  ../../data/Train/CameraRGB/episode_0002_000287...  episode_0002_000287
# 1  ../../data/Train/CameraRGB/episode_0008_000112...  episode_0008_000112
# 2                 ../../data/Train/CameraRGB/804.png                  804
# 3  ../../data/Train/CameraRGB/episode_0008_000286...  episode_0008_000286
# 4               ../../data/Train/CameraRGB/M2-25.png                M2-25
#
#                                                label
# 0  ../../data/Train/CameraSeg/episode_0002_000287...
# 1  ../../data/Train/CameraSeg/episode_0008_000112...
# 2                 ../../data/Train/CameraSeg/804.png
# 3  ../../data/Train/CameraSeg/episode_0008_000286...
# 4               ../../data/Train/CameraSeg/M2-25.png

# %%
from models.segnet import model_segnetVGG16

from models.fcn8 import model_fcn8

model = model_fcn8(3, image_shape=(416, 544, 3), keep_prob=0.7)
model.summary()
# Out:
# /home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 416, 544, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 416, 544, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 416, 544, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 208, 272, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 208, 272, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 208, 272, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 104, 136, 128 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 104, 136, 256 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 104, 136, 256 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 104, 136, 256 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 52, 68, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 52, 68, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 52, 68, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 52, 68, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 26, 34, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 26, 34, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 26, 34, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 26, 34, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 13, 17, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# block6_conv1 (Conv2D)           (None, 13, 17, 4096) 102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# block6_dropout1 (Dropout)       (None, 13, 17, 4096) 0           block6_conv1[0][0]
# __________________________________________________________________________________________________
# block6_conv2 (Conv2D)           (None, 13, 17, 4096) 16781312    block6_dropout1[0][0]
# __________________________________________________________________________________________________
# block6_dropout2 (Dropout)       (None, 13, 17, 4096) 0           block6_conv2[0][0]
# __________________________________________________________________________________________________
# block6_conv3 (Conv2D)           (None, 13, 17, 3)    12291       block6_dropout2[0][0]
# __________________________________________________________________________________________________
# block6_deconv1 (Conv2DTranspose (None, 26, 34, 3)    144         block6_conv3[0][0]
# __________________________________________________________________________________________________
# block7_conv1 (Conv2D)           (None, 26, 34, 3)    1539        block4_pool[0][0]
# __________________________________________________________________________________________________
# block7_Add (Add)                (None, 26, 34, 3)    0           block6_deconv1[0][0]
#                                                                  block7_conv1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 52, 68, 3)    147         block7_Add[0][0]
# __________________________________________________________________________________________________
# block8_conv1 (Conv2D)           (None, 52, 68, 3)    771         block3_pool[0][0]
# __________________________________________________________________________________________________
# block8_Add (Add)                (None, 52, 68, 3)    0           conv2d_transpose_1[0][0]
#                                                                  block8_conv1[0][0]
# __________________________________________________________________________________________________
# block8_Deconv (Conv2DTranspose) (None, 416, 544, 3)  2307        block8_Add[0][0]
# __________________________________________________________________________________________________
# y_ (Activation)                 (None, 416, 544, 3)  0           block8_Deconv[0][0]
# ==================================================================================================
# Total params: 134,277,743
# Trainable params: 119,563,055
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %%
from gen.datagen import oversample_generator_from_df, balanced_generator_from_df

GPUS = 2
BATCH_SIZE = 16 * GPUS
model_dir = '../../saved_models/fcn8/fcn8_v11/'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

from gen.generators import gen_func, preprocess_label, preprocess_multi_label
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input

img_gen_args = dict(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.1, 
                              width_shift_range = 0.1, 
                              rotation_range = 3, 
                              shear_range = 0.01,
                              fill_mode = 'nearest',
                              zoom_range = 0.05)

rgb_gen = ImageDataGenerator(**img_gen_args)
lab_gen = ImageDataGenerator(**img_gen_args)

rgb_gen2 = ImageDataGenerator()
lab_gen2 = ImageDataGenerator()

train_gen = gen_func(train_df, rgb_gen, lab_gen, image_size=(600, 800), target_size=(416, 544), batch_size = BATCH_SIZE)
valid_gen = gen_func(valid_df, rgb_gen2, lab_gen2, image_size=(600, 800), target_size=(416, 544), batch_size = BATCH_SIZE)

# %%
from keras.utils.training_utils import multi_gpu_model

model_gpu = multi_gpu_model(model, GPUS)

model_gpu.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
from train import train_nn

m = train_df.shape[0]
history = train_nn(model_gpu, 
                   train_gen, 
                   valid_gen, 
                   training_size=train_df.shape[0], 
                   batch_size=BATCH_SIZE,
                   validation_size=valid_df.shape[0],
                   output_path=model_dir, 
                   epochs=100,
                   gpus = GPUS)
# Out:
# /home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/engine/training.py:2095: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Epoch 1/100
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# 90/90 [==============================] - 295s 3s/step - loss: 0.2091 - acc: 0.9843 - val_loss: 0.1797 - val_acc: 0.9855
#
# Epoch 00001: val_loss improved from inf to 0.17968, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 2/100
# 90/90 [==============================] - 264s 3s/step - loss: 0.1920 - acc: 0.9841 - val_loss: 0.1643 - val_acc: 0.9842
#
# Epoch 00002: val_loss improved from 0.17968 to 0.16433, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 3/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.1474 - acc: 0.9834 - val_loss: 0.1311 - val_acc: 0.9814
#
# Epoch 00003: val_loss improved from 0.16433 to 0.13107, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 4/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.1031 - acc: 0.9822 - val_loss: 0.0798 - val_acc: 0.9834
#
# Epoch 00004: val_loss improved from 0.13107 to 0.07982, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 5/100
# 90/90 [==============================] - 265s 3s/step - loss: 0.0693 - acc: 0.9824 - val_loss: 0.0637 - val_acc: 0.9843
#
# Epoch 00005: val_loss improved from 0.07982 to 0.06373, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 6/100
# 90/90 [==============================] - 264s 3s/step - loss: 0.0568 - acc: 0.9831 - val_loss: 0.0649 - val_acc: 0.9813
#
# Epoch 00006: val_loss did not improve
# Epoch 7/100
# 90/90 [==============================] - 259s 3s/step - loss: 0.0512 - acc: 0.9835 - val_loss: 0.0655 - val_acc: 0.9806
#
# Epoch 00007: val_loss did not improve
# Epoch 8/100
# 90/90 [==============================] - 253s 3s/step - loss: 0.0481 - acc: 0.9837 - val_loss: 0.0563 - val_acc: 0.9826
#
# Epoch 00008: val_loss improved from 0.06373 to 0.05629, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 9/100
# 90/90 [==============================] - 250s 3s/step - loss: 0.0462 - acc: 0.9838 - val_loss: 0.0547 - val_acc: 0.9824
#
# Epoch 00009: val_loss improved from 0.05629 to 0.05465, saving model to ../../saved_models/fcn8/fcn8_v11//model.hdf5
# Epoch 10/100
# 58/90 [==================>...........] - ETA: 1:10 - loss: 0.0471 - acc: 0.9834
# Process Process-20:
# Process Process-19:
# Process Process-17:
# Process Process-13:
# Process Process-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-18:
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 664, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "<string>", line 2, in put
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py", line 757, in _callmethod
#     kind, result = conn.recv()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 664, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "<string>", line 2, in put
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py", line 757, in _callmethod
#     kind, result = conn.recv()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 663, in _data_generator_task
#     generator_output = next(self._generator)
#   File "../../gen/generators.py", line 109, in gen_func
#     x_new[i] = cv2.resize(preprocess_input(x[i][184:, :, :]) if vgg_preprocess else x[i][184:, :, :], (target_size[1], target_size[0]))
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 663, in _data_generator_task
#     generator_output = next(self._generator)
#   File "../../gen/generators.py", line 103, in gen_func
#     for (x, _), (y, _) in zip(train_rgb_gen, train_lab_gen):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 834, in __next__
#     return self.next(*args, **kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1189, in next
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1150, in _get_batches_of_transformed_samples
#     interpolation=self.interpolation)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 663, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 349, in load_img
#     img = pil_image.open(path)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/PIL/Image.py", line 2557, in open
#     prefix = fp.read(16)
#   File "../../gen/generators.py", line 103, in gen_func
#     for (x, _), (y, _) in zip(train_rgb_gen, train_lab_gen):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 834, in __next__
#     return self.next(*args, **kwargs)
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1189, in next
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1152, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 663, in _data_generator_task
#     generator_output = next(self._generator)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 673, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 226, in apply_transform
#     cval=cval) for x_channel in x]
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 226, in <listcomp>
#     cval=cval) for x_channel in x]
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
#   File "../../gen/generators.py", line 103, in gen_func
#     for (x, _), (y, _) in zip(train_rgb_gen, train_lab_gen):
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 834, in __next__
#     return self.next(*args, **kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1189, in next
#     return self._get_batches_of_transformed_samples(index_array)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 1152, in _get_batches_of_transformed_samples
#     x = self.image_data_generator.random_transform(x)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 673, in random_transform
#     fill_mode=self.fill_mode, cval=self.cval)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 226, in apply_transform
#     cval=cval) for x_channel in x]
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/preprocessing/image.py", line 226, in <listcomp>
#     cval=cval) for x_channel in x]
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/scipy/ndimage/interpolation.py", line 486, in affine_transform
#     output, order, mode, cval, None, None)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-8ed7f6ca5ec1> in <module>()
#      10                    output_path=model_dir,
#      11                    epochs=100,
# ---> 12                    gpus = GPUS)
#
# /data/udacity/lyft_challenge/train.py in train_nn(model, train_gen, valid_gen, training_size, validation_size, output_path, batch_size, epochs, workers, verbose, lr, gpus)
#     157                                 workers=workers,
#     158                                 use_multiprocessing=True,
# --> 159                                 callbacks=callbacks_list
#     160                                 )
#     161
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2242                     outs = self.train_on_batch(x, y,
#    2243                                                sample_weight=sample_weight,
# -> 2244                                                class_weight=class_weight)
#    2245
#    2246                     if not isinstance(outs, list):
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1888             ins = x + y + sample_weights
#    1889         self._make_train_function()
# -> 1890         outputs = self.train_function(ins)
#    1891         if len(outputs) == 1:
#    1892             return outputs[0]
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# # summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# model_gpu.load_weights('../../saved_models/fcn8/fcn8_v11/model.hdf5')
# model.reset_states()
model.save('../../saved_models/fcn8/fcn8_v11/model_saved.h5')
