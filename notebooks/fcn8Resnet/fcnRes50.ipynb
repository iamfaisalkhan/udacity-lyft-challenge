# %%
import sys, os
sys.path.append('../../')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from skimage.io import imread

# %%
from keras.applications.resnet50 import ResNet50
from keras.layers import *

# %%
model = ResNet50(include_top = False, input_shape=(316, 420, 3))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 316, 420, 3)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 158, 210, 64) 9472        input_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 158, 210, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 158, 210, 64) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 78, 104, 64)  0           activation_50[0][0]
# ...

# %%
avg_pool = model.get_layer('avg_pool').output

# %%
x = Conv2D(3, (1, 1), kernel_initializer='he_normal', activation='linear', padding='valid', strides=(1, 1))(avg_pool)
x = UpSampling2D(size=(32, 32))(x)

# %%
new_model = Model()
