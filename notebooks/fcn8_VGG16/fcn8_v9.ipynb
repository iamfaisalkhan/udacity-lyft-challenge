# %%
import sys
import os
sys.path.append('../../')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
import numpy as np

import matplotlib.image as mpimg
import matplotlib.pyplot as plt

from skimage.io import imread

from gen.load_data import load_data

# %%
from sklearn.utils import shuffle

train_df, valid_df, test_df = load_data('../../data')


print(train_df.head())
# Out:
#                                                image                   id  \
# 0  ../../data/Train/CameraRGB/episode_0002_000287...  episode_0002_000287
# 1  ../../data/Train/CameraRGB/episode_0008_000112...  episode_0008_000112
# 2                 ../../data/Train/CameraRGB/804.png                  804
# 3  ../../data/Train/CameraRGB/episode_0008_000286...  episode_0008_000286
# 4               ../../data/Train/CameraRGB/M2-25.png                M2-25
#
#                                                label
# 0  ../../data/Train/CameraSeg/episode_0002_000287...
# 1  ../../data/Train/CameraSeg/episode_0008_000112...
# 2                 ../../data/Train/CameraSeg/804.png
# 3  ../../data/Train/CameraSeg/episode_0008_000286...
# 4               ../../data/Train/CameraSeg/M2-25.png

# %%
from models.segnet import model_segnetVGG16

from models.fcn8 import model_fcn8

model = model_fcn8(3, image_shape=(384, 384, 3), keep_prob=0.7)
model.summary()
# Out:
# /home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 384, 384, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 384, 384, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 384, 384, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 192, 192, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 192, 192, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 192, 192, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 96, 96, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 96, 96, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 96, 96, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 96, 96, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 48, 48, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 48, 48, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 48, 48, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 48, 48, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 24, 24, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 24, 24, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 24, 24, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 24, 24, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 12, 12, 512)  0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# block6_conv1 (Conv2D)           (None, 12, 12, 4096) 102764544   block5_pool[0][0]
# __________________________________________________________________________________________________
# block6_dropout1 (Dropout)       (None, 12, 12, 4096) 0           block6_conv1[0][0]
# __________________________________________________________________________________________________
# block6_conv2 (Conv2D)           (None, 12, 12, 4096) 16781312    block6_dropout1[0][0]
# __________________________________________________________________________________________________
# block6_dropout2 (Dropout)       (None, 12, 12, 4096) 0           block6_conv2[0][0]
# __________________________________________________________________________________________________
# block6_conv3 (Conv2D)           (None, 12, 12, 3)    12291       block6_dropout2[0][0]
# __________________________________________________________________________________________________
# block6_deconv1 (Conv2DTranspose (None, 24, 24, 3)    144         block6_conv3[0][0]
# __________________________________________________________________________________________________
# block7_conv1 (Conv2D)           (None, 24, 24, 3)    1539        block4_pool[0][0]
# __________________________________________________________________________________________________
# block7_Add (Add)                (None, 24, 24, 3)    0           block6_deconv1[0][0]
#                                                                  block7_conv1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 48, 48, 3)    147         block7_Add[0][0]
# __________________________________________________________________________________________________
# block8_conv1 (Conv2D)           (None, 48, 48, 3)    771         block3_pool[0][0]
# __________________________________________________________________________________________________
# block8_Add (Add)                (None, 48, 48, 3)    0           conv2d_transpose_1[0][0]
#                                                                  block8_conv1[0][0]
# __________________________________________________________________________________________________
# block8_Deconv (Conv2DTranspose) (None, 384, 384, 3)  2307        block8_Add[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 147456, 3)    0           block8_Deconv[0][0]
# __________________________________________________________________________________________________
# y_ (Activation)                 (None, 147456, 3)    0           reshape_1[0][0]
# ==================================================================================================
# Total params: 134,277,743
# Trainable params: 134,277,743
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from gen.datagen import oversample_generator_from_df, balanced_generator_from_df

BATCH_SIZE = 32
model_dir = '../../saved_models/fcn8/fcn8_v9/'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

from gen.generators import gen_func, preprocess_label, preprocess_multi_label
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16, preprocess_input

img_gen_args = dict(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range = 0.1, 
                              width_shift_range = 0.1, 
                              rotation_range = 3, 
                              shear_range = 0.01,
                              fill_mode = 'nearest',
                              zoom_range = 0.05)

rgb_gen = ImageDataGenerator(**img_gen_args)
lab_gen = ImageDataGenerator(**img_gen_args)

rgb_gen2 = ImageDataGenerator()
lab_gen2 = ImageDataGenerator()

train_gen = gen_func(train_df, rgb_gen, lab_gen, image_size=(600, 800), target_size=(384, 384), batch_size = BATCH_SIZE)
valid_gen = gen_func(valid_df, rgb_gen2, lab_gen2, image_size=(600, 800), target_size=(384, 384), batch_size = BATCH_SIZE)

# %%
from keras.utils.training_utils import multi_gpu_model

gpus = 2

model_gpu = multi_gpu_model(model, gpus)
model_gpu.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
from train import train_nn

m = train_df.shape[0]
history = train_nn(model_gpu, 
                   train_gen, 
                   valid_gen, 
                   training_size=train_df.shape[0], 
                   batch_size=BATCH_SIZE,
                   validation_size=valid_df.shape[0],
                   output_path=model_dir, 
                   epochs=500,
                   gpus = gpus)
# Out:
# WARNING:tensorflow:From /home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# /home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/engine/training.py:2095: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 1683 images
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Reinserting dataframe: 5804 images
# ## Ignore next message from keras, values are replaced anyways
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Epoch 1/500
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# Reinserting dataframe: 5804 images
# 90/90 [==============================] - 263s 3s/step - loss: 2.7023 - acc: 0.6939 - mean_squared_error: 0.1733 - val_loss: 0.4010 - val_acc: 0.8219 - val_mean_squared_error: 0.0755
#
# Epoch 00001: val_loss improved from inf to 0.40101, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 2/500
# 90/90 [==============================] - 233s 3s/step - loss: 0.3561 - acc: 0.8578 - mean_squared_error: 0.0645 - val_loss: 0.2788 - val_acc: 0.9033 - val_mean_squared_error: 0.0490
#
# Epoch 00002: val_loss improved from 0.40101 to 0.27884, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 3/500
# 90/90 [==============================] - 228s 3s/step - loss: 0.2202 - acc: 0.9306 - mean_squared_error: 0.0352 - val_loss: 0.1375 - val_acc: 0.9637 - val_mean_squared_error: 0.0211
#
# Epoch 00003: val_loss improved from 0.27884 to 0.13752, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 4/500
# 90/90 [==============================] - 228s 3s/step - loss: 0.1520 - acc: 0.9517 - mean_squared_error: 0.0231 - val_loss: 0.1076 - val_acc: 0.9697 - val_mean_squared_error: 0.0164
#
# Epoch 00004: val_loss improved from 0.13752 to 0.10761, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 5/500
# 90/90 [==============================] - 228s 3s/step - loss: 0.1299 - acc: 0.9579 - mean_squared_error: 0.0199 - val_loss: 0.0908 - val_acc: 0.9755 - val_mean_squared_error: 0.0134
#
# Epoch 00005: val_loss improved from 0.10761 to 0.09080, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 6/500
# 90/90 [==============================] - 231s 3s/step - loss: 0.1084 - acc: 0.9661 - mean_squared_error: 0.0162 - val_loss: 0.0730 - val_acc: 0.9804 - val_mean_squared_error: 0.0106
#
# Epoch 00006: val_loss improved from 0.09080 to 0.07303, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 7/500
# 90/90 [==============================] - 236s 3s/step - loss: 0.0876 - acc: 0.9731 - mean_squared_error: 0.0128 - val_loss: 0.0660 - val_acc: 0.9818 - val_mean_squared_error: 0.0094
#
# Epoch 00007: val_loss improved from 0.07303 to 0.06601, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 8/500
# 90/90 [==============================] - 223s 2s/step - loss: 0.0788 - acc: 0.9758 - mean_squared_error: 0.0114 - val_loss: 0.1069 - val_acc: 0.9727 - val_mean_squared_error: 0.0149
#
# Epoch 00008: val_loss did not improve
# Epoch 9/500
# 90/90 [==============================] - 227s 3s/step - loss: 0.0698 - acc: 0.9785 - mean_squared_error: 0.0100 - val_loss: 0.0615 - val_acc: 0.9826 - val_mean_squared_error: 0.0091
#
# Epoch 00009: val_loss improved from 0.06601 to 0.06155, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 10/500
# 90/90 [==============================] - 231s 3s/step - loss: 0.0664 - acc: 0.9795 - mean_squared_error: 0.0094 - val_loss: 0.0610 - val_acc: 0.9830 - val_mean_squared_error: 0.0089
#
# Epoch 00010: val_loss improved from 0.06155 to 0.06104, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 11/500
# 90/90 [==============================] - 233s 3s/step - loss: 0.0603 - acc: 0.9813 - mean_squared_error: 0.0085 - val_loss: 0.0482 - val_acc: 0.9865 - val_mean_squared_error: 0.0070
#
# Epoch 00011: val_loss improved from 0.06104 to 0.04820, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 12/500
# 90/90 [==============================] - 229s 3s/step - loss: 0.0531 - acc: 0.9832 - mean_squared_error: 0.0075 - val_loss: 0.0463 - val_acc: 0.9867 - val_mean_squared_error: 0.0068
#
# Epoch 00012: val_loss improved from 0.04820 to 0.04633, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 13/500
# 90/90 [==============================] - 237s 3s/step - loss: 0.0496 - acc: 0.9840 - mean_squared_error: 0.0070 - val_loss: 0.0470 - val_acc: 0.9860 - val_mean_squared_error: 0.0070
#
# Epoch 00013: val_loss did not improve
# Epoch 14/500
# 90/90 [==============================] - 232s 3s/step - loss: 0.0481 - acc: 0.9843 - mean_squared_error: 0.0068 - val_loss: 0.0438 - val_acc: 0.9870 - val_mean_squared_error: 0.0065
#
# Epoch 00014: val_loss improved from 0.04633 to 0.04383, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 15/500
# 90/90 [==============================] - 232s 3s/step - loss: 0.0451 - acc: 0.9852 - mean_squared_error: 0.0063 - val_loss: 0.0420 - val_acc: 0.9868 - val_mean_squared_error: 0.0064
#
# Epoch 00015: val_loss improved from 0.04383 to 0.04200, saving model to ../../saved_models/fcn8/fcn8_v9//model.hdf5
# Epoch 16/500
#  4/90 [>.............................] - ETA: 2:14 - loss: 0.0422 - acc: 0.9862 - mean_squared_error: 0.0057
# Process Process-4:
# Process Process-5:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-2:
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 664, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 2, in put
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 664, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py", line 757, in _callmethod
#     kind, result = conn.recv()
#   File "<string>", line 2, in put
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py", line 757, in _callmethod
#     kind, result = conn.recv()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 664, in _data_generator_task
#     self.queue.put((True, generator_output))
#   File "<string>", line 2, in put
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py", line 757, in _callmethod
#     kind, result = conn.recv()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 250, in recv
#     buf = self._recv_bytes()
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/home/faisal/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py", line 666, in _data_generator_task
#     time.sleep(self.wait_time)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-c36a4465e903> in <module>()
#      10                    output_path=model_dir,
#      11                    epochs=500,
# ---> 12                    gpus = gpus)
#
# /data/udacity/lyft_challenge/train.py in train_nn(model, train_gen, valid_gen, training_size, validation_size, output_path, batch_size, epochs, workers, verbose, lr, gpus)
#     125                                 workers=workers,
#     126                                 use_multiprocessing=True,
# --> 127                                 callbacks=callbacks_list
#     128                                 )
#     129
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2210                 batch_index = 0
#    2211                 while steps_done < steps_per_epoch:
# -> 2212                     generator_output = next(output_generator)
#    2213
#    2214                     if not hasattr(generator_output, '__len__'):
#
# ~/anaconda3/envs/ai/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     759         while self.is_running():
#     760             if not self.queue.empty():
# --> 761                 success, value = self.queue.get()
#     762                 # Rethrow any exceptions found in the queue
#     763                 if not success:
#
# <string> in get(self, *args, **kwds)
#
# ~/anaconda3/envs/ai/lib/python3.6/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     755
#     756         conn.send((self._id, methodname, args, kwds))
# --> 757         kind, result = conn.recv()
#     758
#     759         if kind == '#RETURN':
#
# ~/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/envs/ai/lib/python3.6/multiprocessing/connection.py in _recv(self, size, read)
#     377         remaining = size
#     378         while remaining > 0:
# --> 379             chunk = read(handle, remaining)
#     380             n = len(chunk)
#     381             if n == 0:
#
# KeyboardInterrupt:

# %%
# # summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model_gpu.load_weights('../../saved_models/fcn8/fcn8_v9/model.hdf5')
model.reset_states()
model.save('../../saved_models/fcn8/fcn8_v9/model_saved.h5')
